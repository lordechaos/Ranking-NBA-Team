# %%
import pandas as pd
import numpy as np
from scipy import linalg as la

# %%
df = pd.read_csv("2016-17_officialBoxScore.csv")

# %%
missing_data = df.isnull()
missing_data = missing_data.sum()
missing_data = missing_data[missing_data > 0]
missing_data
# Out:
# Series([], dtype: int64)

# %%
cols = df.columns.to_list()

# %%
df
# Out:
#           gmDate gmTime  seasTyp   offLNm  offFNm teamAbbr teamConf  \
# 0     2016-10-25  08:00  Regular     Lane    Karl       NY     East
# 1     2016-10-25  08:00  Regular    Adams  Bennie       NY     East
# 2     2016-10-25  08:00  Regular  Kennedy    Bill       NY     East
# 3     2016-10-25  08:00  Regular     Lane    Karl      CLE     East
# 4     2016-10-25  08:00  Regular    Adams  Bennie      CLE     East
# ...          ...    ...      ...      ...     ...      ...      ...
# 7375  2017-04-12  10:30  Regular    Adams  Bennie       NO     West
# 7376  2017-04-12  10:30  Regular    Davis    Marc       NO     West
# 7377  2017-04-12  10:30  Regular  Guthrie   David      POR     West
# 7378  2017-04-12  10:30  Regular    Adams  Bennie      POR     West
# 7379  2017-04-12  10:30  Regular    Davis    Marc      POR     West
#
#         teamDiv teamLoc teamRslt  ...  opptFIC40  opptOrtg  opptDrtg  \
# 0      Atlantic    Away     Loss  ...    84.9585  116.5653   87.6731
# 1      Atlantic    Away     Loss  ...    84.9585  116.5653   87.6731
# 2      Atlantic    Away     Loss  ...    84.9585  116.5653   87.6731
# 3       Central    Home      Win  ...    41.6667   87.6731  116.5653
# 4       Central    Home      Win  ...    41.6667   87.6731  116.5653
# ...         ...     ...      ...  ...        ...       ...       ...
# 7375  Southwest    Away      Win  ...    57.1875  100.9166  103.9441
# 7376  Southwest    Away      Win  ...    57.1875  100.9166  103.9441
# 7377  Northwest    Home     Loss  ...    65.0415  103.9441  100.9166
# 7378  Northwest    Home     Loss  ...    65.0415  103.9441  100.9166
# 7379  Northwest    Home     Loss  ...    65.0415  103.9441  100.9166
#
#       opptEDiff  opptPlay%   opptAR  opptAST/TO  opptSTL/TO      poss  \
# 0       28.8922     0.4592  20.8951      2.0667     80.0000  100.3729
# 1       28.8922     0.4592  20.8951      2.0667     80.0000  100.3729
# 2       28.8922     0.4592  20.8951      2.0667     80.0000  100.3729
# 3      -28.8922     0.3478  12.9969      0.9444     33.3333  100.3729
# 4      -28.8922     0.3478  12.9969      0.9444     33.3333  100.3729
# ...         ...        ...      ...         ...         ...       ...
# 7375    -3.0275     0.4271  15.9744      0.8800     16.0000   99.0917
# 7376    -3.0275     0.4271  15.9744      0.8800     16.0000   99.0917
# 7377     3.0275     0.4444  15.3563      1.8182    118.1818   99.0917
# 7378     3.0275     0.4444  15.3563      1.8182    118.1818   99.0917
# 7379     3.0275     0.4444  15.3563      1.8182    118.1818   99.0917
#
#           pace
# 0     100.3729
# 1     100.3729
# 2     100.3729
# 3      99.9564
# 4      99.9564
# ...        ...
# 7375   98.6805
# 7376   98.6805
# 7377   99.0917
# 7378   99.0917
# 7379   99.0917
#
# [7380 rows x 119 columns]

# %%
cols
# Out:
# ['gmDate',
#  'gmTime',
#  'seasTyp',
#  'offLNm',
#  'offFNm',
#  'teamAbbr',
#  'teamConf',
#  'teamDiv',
#  'teamLoc',
#  'teamRslt',
#  'teamMin',
#  'teamDayOff',
#  'teamPTS',
#  'teamAST',
#  'teamTO',
#  'teamSTL',
#  'teamBLK',
#  'teamPF',
#  'teamFGA',
#  'teamFGM',
#  'teamFG%',
#  'team2PA',
#  'team2PM',
#  'team2P%',
#  'team3PA',
#  'team3PM',
#  'team3P%',
#  'teamFTA',
#  'teamFTM',
#  'teamFT%',
#  'teamORB',
#  'teamDRB',
#  'teamTRB',
#  'teamPTS1',
#  'teamPTS2',
#  'teamPTS3',
#  'teamPTS4',
#  'teamPTS5',
#  'teamPTS6',
#  'teamPTS7',
#  'teamPTS8',
#  'teamTREB%',
#  'teamASST%',
#  'teamTS%',
#  'teamEFG%',
#  'teamOREB%',
#  'teamDREB%',
#  'teamTO%',
#  'teamSTL%',
#  'teamBLK%',
#  'teamBLKR',
#  'teamPPS',
#  'teamFIC',
#  'teamFIC40',
#  'teamOrtg',
#  'teamDrtg',
#  'teamEDiff',
#  'teamPlay%',
#  'teamAR',
#  'teamAST/TO',
#  'teamSTL/TO',
#  'opptAbbr',
#  'opptConf',
#  'opptDiv',
#  'opptLoc',
#  'opptRslt',
#  'opptMin',
#  'opptDayOff',
#  'opptPTS',
#  'opptAST',
#  'opptTO',
#  'opptSTL',
#  'opptBLK',
#  'opptPF',
#  'opptFGA',
#  'opptFGM',
#  'opptFG%',
#  'oppt2PA',
#  'oppt2PM',
#  'oppt2P%',
#  'oppt3PA',
#  'oppt3PM',
#  'oppt3P%',
#  'opptFTA',
#  'opptFTM',
#  'opptFT%',
#  'opptORB',
#  'opptDRB',
#  'opptTRB',
#  'opptPTS1',
#  'opptPTS2',
#  'opptPTS3',
#  'opptPTS4',
#  'opptPTS5',
#  'opptPTS6',
#  'opptPTS7',
#  'opptPTS8',
#  'opptTREB%',
#  'opptASST%',
#  'opptTS%',
#  'opptEFG%',
#  'opptOREB%',
#  'opptDREB%',
#  'opptTO%',
#  'opptSTL%',
#  'opptBLK%',
#  'opptBLKR',
#  'opptPPS',
#  'opptFIC',
#  'opptFIC40',
#  'opptOrtg',
#  'opptDrtg',
#  'opptEDiff',
#  'opptPlay%',
#  'opptAR',
#  'opptAST/TO',
#  'opptSTL/TO',
#  'poss',
#  'pace']

# %%
# choose the useful columns
df_use = df[['gmDate', 'teamAbbr', 'teamPTS', 'opptAbbr', 'opptPTS']]
df_use = df_use.drop_duplicates(keep='first').reset_index(drop = True)
df_use
# Out:
#           gmDate teamAbbr  teamPTS opptAbbr  opptPTS
# 0     2016-10-25       NY       88      CLE      117
# 1     2016-10-25      CLE      117       NY       88
# 2     2016-10-25      UTA      104      POR      113
# 3     2016-10-25      POR      113      UTA      104
# 4     2016-10-25       SA      129       GS      100
# ...          ...      ...      ...      ...      ...
# 2455  2017-04-12       GS      109      LAL       94
# 2456  2017-04-12      SAC       95      LAC      115
# 2457  2017-04-12      LAC      115      SAC       95
# 2458  2017-04-12       NO      103      POR      100
# 2459  2017-04-12      POR      100       NO      103
#
# [2460 rows x 5 columns]

# %%
# calculate the point difference between teams
games = []
for idx, row in df_use.iterrows():
    if row[2] < row[4]:
        loser = row[1]
        winner = row[3]
        ptsDiff = row[4] - row[2]
    else:
        loser = row[3]
        winner = row[1]
        ptsDiff = row[2] - row[4]
    if [winner, loser, ptsDiff] not in games:
        games.append([winner, loser, ptsDiff])

# %%
games
# Out:
# [['CLE', 'NY', 29],
#  ['POR', 'UTA', 9],
#  ['SA', 'GS', 29],
#  ['IND', 'DAL', 9],
#  ['MIA', 'ORL', 12],
#  ['BOS', 'BKN', 5],
#  ['TOR', 'DET', 18],
#  ['MEM', 'MIN', 4],
#  ['CHA', 'MIL', 11],
#  ['DEN', 'NO', 5],
#  ['OKC', 'PHI', 6],
#  ['SAC', 'PHO', 19],
#  ['LAL', 'HOU', 6],
#  ['ATL', 'WAS', 15],
#  ['CHI', 'BOS', 6],
#  ['LAC', 'POR', 8],
#  ['SA', 'SAC', 8],
#  ['CLE', 'TOR', 3],
#  ['BKN', 'IND', 9],
#  ['DET', 'ORL', 26],
#  ['CHA', 'MIA', 6],
#  ['OKC', 'PHO', 3],
#  ['HOU', 'DAL', 8],
#  ['UTA', 'LAL', 7],
#  ['GS', 'NO', 8],
#  ['ATL', 'PHI', 32],
#  ['BOS', 'CHA', 6],
#  ['CLE', 'ORL', 6],
#  ['NY', 'MEM', 7],
#  ['CHI', 'IND', 17],
#  ['MIL', 'BKN', 2],
#  ['SA', 'NO', 19],
#  ['POR', 'DEN', 2],
#  ['SAC', 'MIN', 3],
#  ['LAC', 'UTA', 13],
#  ['DET', 'MIL', 15],
#  ['SA', 'MIA', 7],
#  ['GS', 'PHO', 6],
#  ['MEM', 'WAS', 9],
#  ['OKC', 'LAL', 17],
#  ['HOU', 'DAL', 1],
#  ['ATL', 'SAC', 11],
#  ['CHI', 'BKN', 30],
#  ['TOR', 'DEN', 3],
#  ['LAC', 'PHO', 18],
#  ['CLE', 'HOU', 8],
#  ['IND', 'LAL', 7],
#  ['ORL', 'PHI', 2],
#  ['DET', 'NY', 13],
#  ['MIA', 'SAC', 12],
#  ['MIN', 'MEM', 36],
#  ['MIL', 'NO', 4],
#  ['UTA', 'SA', 15],
#  ['GS', 'POR', 23],
#  ['CHA', 'PHI', 16],
#  ['TOR', 'WAS', 10],
#  ['LAL', 'ATL', 7],
#  ['BKN', 'DET', 8],
#  ['HOU', 'NY', 19],
#  ['BOS', 'CHI', 7],
#  ['MEM', 'NO', 6],
#  ['UTA', 'DAL', 16],
#  ['PHO', 'POR', 3],
#  ['OKC', 'LAC', 2],
#  ['ORL', 'SAC', 8],
#  ['CLE', 'BOS', 6],
#  ['MIL', 'IND', 18],
#  ['DEN', 'MIN', 3],
#  ['GS', 'OKC', 26],
#  ['WAS', 'ATL', 3],
#  ['CHA', 'BKN', 4],
#  ['TOR', 'MIA', 9],
#  ['NY', 'CHI', 13],
#  ['LAC', 'MEM', 11],
#  ['PHO', 'NO', 1],
#  ['POR', 'DAL', 10],
#  ['SA', 'UTA', 14],
#  ['LAL', 'GS', 20],
#  ['OKC', 'MIN', 20],
#  ['DET', 'DEN', 17],
#  ['IND', 'CHI', 17],
#  ['ORL', 'WAS', 2],
#  ['CLE', 'PHI', 1],
#  ['ATL', 'HOU', 15],
#  ['MIL', 'SAC', 26],
#  ['LAC', 'SA', 24],
#  ['POR', 'MEM', 6],
#  ['SAC', 'TOR', 5],
#  ['DAL', 'MIL', 11],
#  ['DEN', 'BOS', 16],
#  ['LAL', 'PHO', 11],
#  ['UTA', 'NY', 5],
#  ['CHA', 'IND', 22],
#  ['UTA', 'PHI', 25],
#  ['HOU', 'WAS', 8],
#  ['CHI', 'ORL', 32],
#  ['OKC', 'MIA', 12],
#  ['GS', 'NO', 10],
#  ['LAC', 'DET', 32],
#  ['ATL', 'CLE', 4],
#  ['BKN', 'MIN', 9],
#  ['MEM', 'DEN', 1],
#  ['POR', 'PHO', 3],
#  ['DAL', 'LAL', 12],
#  ['SAC', 'NO', 8],
#  ['CHA', 'UTA', 6],
#  ['IND', 'PHI', 7],
#  ['NY', 'BKN', 14],
#  ['MIN', 'ORL', 16],
#  ['WAS', 'BOS', 25],
#  ['ATL', 'CHI', 8],
#  ['TOR', 'OKC', 10],
#  ['PHO', 'DET', 7],
#  ['HOU', 'SA', 2],
#  ['GS', 'DAL', 21],
#  ['LAC', 'POR', 31],
#  ['CHI', 'MIA', 3],
#  ['NO', 'MIL', 6],
#  ['GS', 'DEN', 24],
#  ['LAL', 'SAC', 10],
#  ['TOR', 'CHA', 2],
#  ['UTA', 'ORL', 13],
#  ['PHI', 'IND', 4],
#  ['CLE', 'WAS', 11],
#  ['BOS', 'NY', 28],
#  ['LAC', 'OKC', 2],
#  ['SA', 'DET', 10],
#  ['POR', 'SAC', 2],
#  ['BOS', 'IND', 6],
#  ['LAL', 'NO', 27],
#  ['ATL', 'PHI', 21],
#  ['TOR', 'NY', 11],
#  ['CHI', 'WAS', 11],
#  ['SA', 'HOU', 6],
#  ['UTA', 'MIA', 11],
#  ['LAC', 'MIN', 14],
#  ['MIL', 'MEM', 10],
#  ['DET', 'DEN', 11],
#  ['BKN', 'PHO', 18],
#  ['CLE', 'CHA', 7],
#  ['MIN', 'LAL', 26],
#  ['ORL', 'OKC', 2],
#  ['GS', 'PHO', 13],
#  ['POR', 'DEN', 7],
#  ['IND', 'ORL', 19],
#  ['DET', 'OKC', 16],
#  ['NY', 'DAL', 16],
#  ['HOU', 'PHI', 27],
#  ['NO', 'BOS', 1],
#  ['SA', 'MIA', 4],
#  ['MEM', 'UTA', 6],
#  ['LAC', 'BKN', 32],
#  ['CLE', 'TOR', 4],
#  ['ATL', 'MIA', 3],
#  ['CHA', 'MIN', 7],
#  ['CHI', 'POR', 25],
#  ['LAL', 'BKN', 7],
#  ['IND', 'CLE', 10],
#  ['ORL', 'NO', 7],
#  ['PHI', 'WAS', 7],
#  ['ATL', 'MIL', 7],
#  ['BOS', 'DAL', 7],
#  ['NY', 'DET', 3],
#  ['OKC', 'HOU', 2],
#  ['GS', 'TOR', 6],
#  ['DEN', 'PHO', 16],
#  ['MEM', 'LAC', 4],
#  ['SA', 'SAC', 5],
#  ['WAS', 'NY', 7],
#  ['MIA', 'MIL', 23],
#  ['HOU', 'POR', 17],
#  ['MIN', 'PHI', 24],
#  ['CHI', 'UTA', 8],
#  ['CHA', 'ATL', 4],
#  ['PHO', 'IND', 20],
#  ['CLE', 'DET', 23],
#  ['GS', 'BOS', 16],
#  ['NO', 'POR', 12],
#  ['OKC', 'BKN', 19],
#  ['MEM', 'DAL', 16],
#  ['TOR', 'DEN', 2],
#  ['SA', 'LAL', 9],
#  ['LAC', 'SAC', 6],
#  ['HOU', 'UTA', 9],
#  ['BOS', 'DET', 2],
#  ['NO', 'CHA', 5],
#  ['ORL', 'DAL', 8],
#  ['MIA', 'WAS', 3],
#  ['PHI', 'PHO', 15],
#  ['MEM', 'MIN', 22],
#  ['GS', 'MIL', 3],
#  ['LAC', 'CHI', 7],
#  ['NY', 'ATL', 10],
#  ['POR', 'BKN', 20],
#  ['IND', 'OKC', 4],
#  ['DEN', 'UTA', 14],
#  ['SAC', 'TOR', 3],
#  ['CHI', 'LAL', 8],
#  ['MEM', 'CHA', 15],
#  ['GS', 'IND', 37],
#  ['PHI', 'MIA', 7],
#  ['WAS', 'PHO', 5],
#  ['HOU', 'DET', 3],
#  ['MIL', 'ORL', 4],
#  ['BOS', 'MIN', 6],
#  ['SA', 'DAL', 5],
#  ['LAC', 'TOR', 8],
#  ['NO', 'ATL', 18],
#  ['NY', 'POR', 4],
#  ['DEN', 'CHI', 3],
#  ['LAL', 'OKC', 2],
#  ['SA', 'CHA', 5],
#  ['CLE', 'POR', 12],
#  ['ATL', 'IND', 11],
#  ['PHO', 'ORL', 5],
#  ['MEM', 'PHI', 5],
#  ['BOS', 'BKN', 19],
#  ['DET', 'MIA', 23],
#  ['TOR', 'HOU', 13],
#  ['LAC', 'DAL', 20],
#  ['UTA', 'DEN', 25],
#  ['NO', 'MIN', 21],
#  ['GS', 'LAL', 43],
#  ['SAC', 'OKC', 15],
#  ['SA', 'BOS', 6],
#  ['WAS', 'ORL', 3],
#  ['CLE', 'DAL', 38],
#  ['DET', 'LAC', 11],
#  ['NY', 'CHA', 2],
#  ['CHI', 'PHI', 16],
#  ['IND', 'BKN', 21],
#  ['MIA', 'MEM', 9],
#  ['TOR', 'MIL', 6],
#  ['UTA', 'ATL', 27],
#  ['OKC', 'DEN', 3],
#  ['MIN', 'PHO', 13],
#  ['POR', 'NO', 15],
#  ['GS', 'LAL', 24],
#  ['HOU', 'SAC', 13],
#  ['CHA', 'NY', 5],
#  ['SA', 'WAS', 12],
#  ['MEM', 'MIA', 3],
#  ['OKC', 'DET', 18],
#  ['GS', 'MIN', 13],
#  ['CLE', 'PHI', 4],
#  ['DEN', 'PHO', 6],
#  ['SAC', 'BKN', 17],
#  ['IND', 'LAC', 21],
#  ['MIL', 'ORL', 8],
#  ['DAL', 'NO', 10],
#  ['HOU', 'POR', 16],
#  ['LAL', 'ATL', 15],
#  ['WAS', 'SAC', 6],
#  ['BOS', 'MIA', 8],
#  ['OKC', 'NY', 9],
#  ['TOR', 'PHI', 27],
#  ['CHA', 'MEM', 19],
#  ['UTA', 'MIN', 9],
#  ['GS', 'ATL', 5],
#  ['DET', 'CHA', 23],
#  ['BKN', 'LAC', 5],
#  ['MIL', 'CLE', 17],
#  ['NO', 'LAL', 17],
#  ['ORL', 'SA', 12],
#  ['UTA', 'HOU', 19],
#  ['DET', 'BOS', 7],
#  ['TOR', 'MEM', 15],
#  ['LAL', 'CHI', 6],
#  ['NY', 'MIN', 2],
#  ['OKC', 'WAS', 11],
#  ['SA', 'DAL', 7],
#  ['MIA', 'DEN', 8],
#  ['PHO', 'ATL', 2],
#  ['POR', 'IND', 22],
#  ['CHA', 'DAL', 10],
#  ['MIL', 'BKN', 18],
#  ['LAC', 'CLE', 19],
#  ['MEM', 'ORL', 1],
#  ['MIA', 'UTA', 1],
#  ['HOU', 'GS', 5],
#  ['ORL', 'PHI', 17],
#  ['BOS', 'SAC', 5],
#  ['NY', 'MIN', 4],
#  ['TOR', 'LAL', 33],
#  ['DET', 'ATL', 36],
#  ['CHI', 'CLE', 6],
#  ['LAC', 'NO', 18],
#  ['SA', 'WAS', 2],
#  ['HOU', 'DEN', 18],
#  ['MIL', 'BKN', 9],
#  ['MIN', 'CHA', 5],
#  ['BOS', 'PHI', 1],
#  ['TOR', 'ATL', 44],
#  ['MEM', 'LAL', 3],
#  ['DAL', 'CHI', 25],
#  ['UTA', 'DEN', 7],
#  ['POR', 'MIA', 7],
#  ['GS', 'PHO', 29],
#  ['ORL', 'DET', 6],
#  ['OKC', 'NO', 9],
#  ['NY', 'SAC', 8],
#  ['IND', 'LAC', 9],
#  ['DEN', 'PHI', 8],
#  ['OKC', 'ATL', 3],
#  ['WAS', 'BKN', 5],
#  ['POR', 'CHI', 2],
#  ['HOU', 'BOS', 1],
#  ['SA', 'MIL', 1],
#  ['MEM', 'NO', 2],
#  ['CHA', 'DAL', 8],
#  ['GS', 'IND', 36],
#  ['UTA', 'LAL', 6],
#  ['ORL', 'WAS', 8],
#  ['DET', 'CHI', 11],
#  ['NY', 'MIA', 11],
#  ['SA', 'MIN', 14],
#  ['UTA', 'PHO', 7],
#  ['CHA', 'DET', 10],
#  ['BOS', 'ORL', 30],
#  ['ATL', 'MIA', 8],
#  ['BKN', 'DEN', 5],
#  ['HOU', 'LAL', 39],
#  ['MIL', 'POR', 8],
#  ['CLE', 'NY', 32],
#  ['SAC', 'DAL', 31],
#  ['IND', 'PHO', 15],
#  ['GS', 'LAC', 17],
#  ['TOR', 'MIN', 14],
#  ['WAS', 'DEN', 7],
#  ['MEM', 'POR', 2],
#  ['PHI', 'NO', 11],
#  ['GS', 'UTA', 7],
#  ['CHI', 'SA', 4],
#  ['CHA', 'ORL', 21],
#  ['TOR', 'BOS', 7],
#  ['CLE', 'MIA', 30],
#  ['ATL', 'MIL', 4],
#  ['DET', 'MIN', 27],
#  ['HOU', 'OKC', 3],
#  ['DAL', 'IND', 8],
#  ['PHO', 'LAL', 4],
#  ['NY', 'SAC', 3],
#  ['IND', 'POR', 7],
#  ['DEN', 'ORL', 8],
#  ['WAS', 'MIL', 5],
#  ['CLE', 'CHA', 11],
#  ['CHI', 'MIA', 5],
#  ['HOU', 'DAL', 22],
#  ['MEM', 'GS', 21],
#  ['SA', 'BKN', 29],
#  ['UTA', 'SAC', 20],
#  ['LAC', 'NO', 28],
#  ['PHI', 'DET', 18],
#  ['GS', 'MIN', 8],
#  ['OKC', 'BOS', 3],
#  ['NO', 'PHO', 1],
#  ['NY', 'LAL', 6],
#  ['IND', 'CHA', 16],
#  ['MIA', 'WAS', 11],
#  ['TOR', 'MIL', 22],
#  ['HOU', 'BKN', 4],
#  ['DAL', 'DEN', 20],
#  ['LAC', 'POR', 1],
#  ['SAC', 'LAL', 24],
#  ['CLE', 'MEM', 17],
#  ['ORL', 'ATL', 11],
#  ['MIN', 'CHI', 5],
#  ['GS', 'NO', 4],
#  ['PHO', 'NY', 2],
#  ['POR', 'OKC', 19],
#  ['MIA', 'IND', 6],
#  ['LAC', 'ORL', 5],
#  ['TOR', 'PHI', 9],
#  ['WAS', 'CHA', 3],
#  ['BKN', 'LAL', 10],
#  ['HOU', 'SAC', 34],
#  ['MEM', 'CLE', 8],
#  ['DET', 'DAL', 10],
#  ['UTA', 'OKC', 20],
#  ['SA', 'BOS', 7],
#  ['MIL', 'CHI', 11],
#  ['NO', 'IND', 7],
#  ['DEN', 'POR', 12],
#  ['SA', 'PHO', 15],
#  ['GS', 'NY', 13],
#  ['ORL', 'BKN', 7],
#  ['WAS', 'DET', 14],
#  ['BOS', 'CHA', 8],
#  ['ATL', 'TOR', 4],
#  ['MIL', 'CHI', 26],
#  ['HOU', 'NO', 22],
#  ['SAC', 'MEM', 4],
#  ['LAC', 'MIA', 4],
#  ['LAL', 'PHI', 11],
#  ['UTA', 'DAL', 3],
#  ['OKC', 'PHO', 13],
#  ['IND', 'DET', 15],
#  ['CHA', 'ATL', 8],
#  ['CLE', 'LAL', 11],
#  ['HOU', 'MIN', 2],
#  ['DEN', 'NY', 13],
#  ['GS', 'POR', 45],
#  ['WAS', 'LAC', 7],
#  ['UTA', 'MEM', 9],
#  ['BOS', 'MIA', 10],
#  ['TOR', 'ORL', 30],
#  ['PHI', 'BKN', 1],
#  ['DAL', 'SAC', 20],
#  ['SA', 'NO', 13],
#  ['IND', 'WAS', 2],
#  ['CHI', 'DET', 31],
#  ['MIN', 'PHO', 7],
#  ['ATL', 'OKC', 2],
#  ['DEN', 'DAL', 10],
#  ['CHA', 'LAL', 4],
#  ['NO', 'PHI', 15],
#  ['ORL', 'MIA', 6],
#  ['NY', 'IND', 7],
#  ['TOR', 'BKN', 12],
#  ['SA', 'HOU', 2],
#  ['BOS', 'MEM', 3],
#  ['CLE', 'MIL', 6],
#  ['GS', 'UTA', 30],
#  ['LAC', 'DEN', 17],
#  ['SAC', 'POR', 5],
#  ['CLE', 'MIL', 11],
#  ['MIN', 'ATL', 8],
#  ['MEM', 'DET', 12],
#  ['WAS', 'CHI', 10],
#  ['OKC', 'NO', 11],
#  ['HOU', 'PHO', 14],
#  ['SAC', 'UTA', 1],
#  ['DAL', 'POR', 1],
#  ['GS', 'BKN', 16],
#  ['MIA', 'LAL', 8],
#  ['NY', 'ORL', 11],
#  ['BOS', 'IND', 7],
#  ['LAC', 'SA', 5],
#  ['CHA', 'CHI', 12],
#  ['ORL', 'LAL', 19],
#  ['OKC', 'BOS', 5],
#  ['CLE', 'BKN', 20],
#  ['GS', 'DET', 6],
#  ['MEM', 'HOU', 6],
#  ['MIL', 'WAS', 27],
#  ['SAC', 'MIN', 4],
#  ['NO', 'MIA', 4],
#  ['ATL', 'DEN', 1],
#  ['PHO', 'PHI', 7],
#  ['TOR', 'UTA', 6],
#  ['SA', 'POR', 20],
#  ['DAL', 'LAC', 2],
#  ['CLE', 'GS', 1],
#  ['SA', 'CHI', 19],
#  ['OKC', 'MIN', 12],
#  ['LAL', 'LAC', 9],
#  ['BOS', 'NY', 5],
#  ['ORL', 'MEM', 10],
#  ['BKN', 'CHA', 2],
#  ['DET', 'CLE', 16],
#  ['CHI', 'IND', 5],
#  ['HOU', 'PHO', 16],
#  ['MIN', 'ATL', 14],
#  ['NO', 'DAL', 7],
#  ['TOR', 'POR', 4],
#  ['DEN', 'LAC', 4],
#  ['SAC', 'PHI', 2],
#  ['BOS', 'MEM', 10],
#  ['HOU', 'DAL', 16],
#  ['UTA', 'LAL', 2],
#  ['CHA', 'ORL', 19],
#  ['WAS', 'IND', 6],
#  ['ATL', 'NY', 4],
#  ['MIL', 'DET', 25],
#  ['CHI', 'BKN', 2],
#  ['NO', 'LAC', 4],
#  ['SA', 'PHO', 21],
#  ['DEN', 'MIN', 2],
#  ['POR', 'SAC', 13],
#  ['GS', 'TOR', 10],
#  ['CHA', 'MIA', 9],
#  ['MEM', 'OKC', 34],
#  ['PHO', 'TOR', 8],
#  ['UTA', 'PHI', 17],
#  ['IND', 'CHI', 10],
#  ['WAS', 'BKN', 23],
#  ['BOS', 'MIA', 3],
#  ['ATL', 'DET', 7],
#  ['HOU', 'LAC', 24],
#  ['MIN', 'MIL', 17],
#  ['NO', 'NY', 12],
#  ['SA', 'POR', 16],
#  ['PHI', 'DEN', 2],
#  ['GS', 'DAL', 9],
#  ['MEM', 'SAC', 14],
#  ['MIL', 'CHI', 20],
#  ['CLE', 'CHA', 12],
#  ['HOU', 'NY', 7],
#  ['OKC', 'LAC', 26],
#  ['UTA', 'PHO', 5],
#  ['ATL', 'SA', 2],
#  ['IND', 'ORL', 13],
#  ['DET', 'MIA', 9],
#  ['POR', 'MIN', 6],
#  ['TOR', 'LAL', 9],
#  ['CLE', 'NO', 8],
#  ['MIL', 'OKC', 4],
#  ['UTA', 'BKN', 12],
#  ['ORL', 'NY', 12],
#  ['CHI', 'CHA', 7],
#  ['HOU', 'WAS', 10],
#  ['GS', 'DEN', 8],
#  ['LAC', 'PHO', 11],
#  ['PHI', 'MIN', 2],
#  ['BOS', 'UTA', 11],
#  ['IND', 'DET', 5],
#  ['DAL', 'WAS', 8],
#  ['SA', 'TOR', 28],
#  ['SAC', 'DEN', 7],
#  ['PHO', 'MIA', 9],
#  ['LAL', 'MEM', 14],
#  ['CHA', 'OKC', 11],
#  ['ATL', 'ORL', 19],
#  ['MIL', 'NY', 1],
#  ['CHI', 'CLE', 12],
#  ['GS', 'POR', 8],
#  ['LAC', 'MEM', 9],
#  ['MIA', 'SAC', 5],
#  ['IND', 'BKN', 12],
#  ['DET', 'CHA', 1],
#  ['TOR', 'UTA', 8],
#  ['HOU', 'OKC', 2],
#  ['ATL', 'NO', 5],
#  ['PHO', 'DAL', 7],
#  ['POR', 'LAL', 9],
#  ['SA', 'DEN', 28],
#  ['HOU', 'ORL', 7],
#  ['WAS', 'MIN', 7],
#  ['BOS', 'PHI', 4],
#  ['CLE', 'BKN', 8],
#  ['NY', 'MIL', 5],
#  ['MEM', 'GS', 9],
#  ['LAL', 'MIA', 27],
#  ['LAC', 'SAC', 8],
#  ['IND', 'NY', 14],
#  ['BOS', 'NO', 9],
#  ['CHI', 'TOR', 5],
#  ['UTA', 'MIN', 2],
#  ['OKC', 'DEN', 15],
#  ['ATL', 'DAL', 15],
#  ['SA', 'CHA', 17],
#  ['LAC', 'MIA', 12],
#  ['WAS', 'MIL', 6],
#  ['HOU', 'TOR', 7],
#  ['MEM', 'UTA', 9],
#  ['CLE', 'PHO', 4],
#  ['GS', 'SAC', 11],
#  ['LAL', 'ORL', 16],
#  ['PHI', 'BKN', 10],
#  ['DET', 'POR', 1],
#  ['NO', 'NY', 14],
#  ['OKC', 'CHI', 15],
#  ['MIN', 'DAL', 9],
#  ['WAS', 'CHI', 2],
#  ['ATL', 'BKN', 20],
#  ['TOR', 'BOS', 8],
#  ['HOU', 'CHA', 7],
#  ['MIL', 'SA', 2],
#  ['UTA', 'CLE', 8],
#  ['GS', 'MIA', 12],
#  ['POR', 'LAL', 21],
#  ['SAC', 'DET', 6],
#  ['PHI', 'NY', 1],
#  ['BOS', 'WAS', 9],
#  ['MIN', 'HOU', 14],
#  ['OKC', 'MEM', 8],
#  ['LAC', 'ORL', 9],
#  ['POR', 'CLE', 16],
#  ['DEN', 'IND', 28],
#  ['NO', 'BKN', 9],
#  ['NY', 'CHI', 15],
#  ['SA', 'LAL', 40],
#  ['DAL', 'PHO', 5],
#  ['GS', 'DET', 20],
#  ['PHI', 'CHA', 9],
#  ['TOR', 'BKN', 19],
#  ['BOS', 'ATL', 2],
#  ['MEM', 'HOU', 5],
#  ['MIL', 'MIA', 8],
#  ['MIN', 'OKC', 10],
#  ['ORL', 'POR', 6],
#  ['CLE', 'SAC', 12],
#  ['UTA', 'DET', 33],
#  ['LAC', 'LAL', 16],
#  ['CHI', 'NO', 8],
#  ['PHO', 'SA', 3],
#  ['WAS', 'PHI', 16],
#  ['UTA', 'ORL', 7],
#  ['ATL', 'MIL', 13],
#  ['TOR', 'NY', 15],
#  ['DAL', 'MIN', 11],
#  ['HOU', 'BKN', 25],
#  ['CHI', 'MEM', 4],
#  ['OKC', 'SAC', 4],
#  ['DET', 'LAL', 5],
#  ['ATL', 'NY', 1],
#  ['WAS', 'POR', 19],
#  ['PHI', 'MIL', 9],
#  ['IND', 'NO', 3],
#  ['DEN', 'ORL', 13],
#  ['BOS', 'CHA', 10],
#  ['GS', 'CLE', 35],
#  ['LAC', 'OKC', 22],
#  ['TOR', 'BKN', 10],
#  ['MIA', 'HOU', 6],
#  ['DAL', 'CHI', 1],
#  ['SA', 'MIN', 8],
#  ['DEN', 'LAL', 6],
#  ['CHA', 'POR', 22],
#  ['PHI', 'TOR', 5],
#  ['WAS', 'MEM', 3],
#  ['NY', 'BOS', 11],
#  ['DET', 'ATL', 23],
#  ['HOU', 'MIL', 19],
#  ['NO', 'ORL', 20],
#  ['GS', 'OKC', 21],
#  ['IND', 'SAC', 6],
#  ['CLE', 'PHO', 15],
#  ['MIA', 'DAL', 4],
#  ['WAS', 'NY', 3],
#  ['SA', 'DEN', 14],
#  ['MIN', 'LAC', 3],
#  ['CHA', 'TOR', 35],
#  ['ORL', 'MIL', 16],
#  ['PHI', 'POR', 1],
#  ['ATL', 'CHI', 9],
#  ['GS', 'HOU', 17],
#  ['MEM', 'SAC', 16],
#  ['BKN', 'NO', 29],
#  ['UTA', 'DAL', 5],
#  ['LAL', 'IND', 12],
#  ['POR', 'BOS', 4],
#  ['DET', 'WAS', 1],
#  ['ATL', 'PHI', 17],
#  ['CHA', 'BKN', 7],
#  ['MIA', 'MIL', 12],
#  ['HOU', 'MEM', 24],
#  ['SA', 'CLE', 3],
#  ['CHI', 'SAC', 3],
#  ['DEN', 'LAC', 25],
#  ['UTA', 'IND', 9],
#  ['DAL', 'LAL', 49],
#  ['PHO', 'TOR', 12],
#  ['MIN', 'DEN', 3],
#  ['GS', 'ORL', 20],
#  ['WAS', 'CHA', 10],
#  ['LAC', 'ATL', 10],
#  ['SA', 'BKN', 26],
#  ['SAC', 'DET', 5],
#  ['MIA', 'GS', 3],
#  ['NY', 'IND', 6],
#  ['MIL', 'HOU', 13],
#  ['NO', 'CLE', 2],
#  ['OKC', 'UTA', 2],
#  ['CHI', 'ORL', 8],
#  ['PHI', 'LAC', 11],
#  ['SA', 'TOR', 2],
#  ['WAS', 'BOS', 15],
#  ['DEN', 'UTA', 10],
#  ['MIN', 'PHO', 1],
#  ['SAC', 'CLE', 4],
#  ['BOS', 'HOU', 11],
#  ['MIA', 'BKN', 3],
#  ['ATL', 'CHI', 5],
#  ['GS', 'CHA', 10],
#  ['MEM', 'TOR', 2],
#  ['PHI', 'MIL', 5],
#  ['DAL', 'NY', 8],
#  ['POR', 'LAL', 7],
#  ['IND', 'MIN', 6],
#  ['OKC', 'DAL', 11],
#  ['DEN', 'PHO', 7],
#  ['UTA', 'LAL', 8],
#  ['IND', 'SAC', 4],
#  ['HOU', 'PHI', 5],
#  ['NY', 'CHA', 3],
#  ['TOR', 'MIL', 16],
#  ['WAS', 'ATL', 26],
#  ['MIA', 'CHI', 12],
#  ['NO', 'SA', 16],
#  ['POR', 'MEM', 3],
#  ['SAC', 'CHA', 3],
#  ['MIA', 'DET', 13],
#  ['BOS', 'MIL', 4],
#  ['GS', 'LAC', 46],
#  ['MIN', 'BKN', 20],
#  ['DEN', 'PHO', 11],
#  ['MEM', 'UTA', 7],
#  ['ATL', 'NY', 3],
#  ['CLE', 'OKC', 16],
#  ['IND', 'HOU', 19],
#  ['WAS', 'NO', 13],
#  ['ORL', 'TOR', 1],
#  ['CHI', 'PHI', 13],
#  ['DAL', 'SA', 4],
#  ['GS', 'POR', 2],
#  ['MIA', 'BKN', 8],
#  ['BOS', 'DET', 4],
#  ['MIN', 'ORL', 6],
#  ['DAL', 'CLE', 7],
#  ['MEM', 'PHO', 19],
#  ['PHI', 'SAC', 3],
#  ['WAS', 'NY', 16],
#  ['TOR', 'NO', 2],
#  ['HOU', 'SAC', 22],
#  ['SA', 'OKC', 14],
#  ['POR', 'CHA', 17],
#  ['LAL', 'DEN', 4],
#  ['CLE', 'MIN', 28],
#  ['IND', 'ORL', 10],
#  ['BOS', 'TOR', 5],
#  ['NY', 'BKN', 5],
#  ['DET', 'NO', 20],
#  ['MIA', 'ATL', 23],
#  ['DAL', 'PHI', 18],
#  ['MEM', 'DEN', 20],
#  ['LAC', 'PHO', 10],
#  ['UTA', 'MIL', 16],
#  ['CHI', 'OKC', 28],
#  ['GS', 'CHA', 15],
#  ['WAS', 'LAL', 8],
#  ['ATL', 'HOU', 5],
#  ['SA', 'PHI', 16],
#  ['GS', 'LAC', 13],
#  ['ORL', 'TOR', 8],
#  ['IND', 'BKN', 9],
#  ['DET', 'MIN', 8],
#  ['BOS', 'LAL', 6],
#  ['HOU', 'CHI', 4],
#  ['OKC', 'MEM', 12],
#  ['DEN', 'MIL', 4],
#  ['DAL', 'POR', 4],
#  ['PHO', 'SAC', 2],
#  ['ATL', 'ORL', 27],
#  ['IND', 'DET', 21],
#  ['WAS', 'NO', 14],
#  ['MIA', 'PHI', 23],
#  ['CLE', 'NY', 7],
#  ['MEM', 'MIN', 8],
#  ['MIL', 'PHO', 25],
#  ['SA', 'DEN', 24],
#  ['UTA', 'CHA', 7],
#  ['SAC', 'GS', 3],
#  ['BOS', 'LAC', 5],
#  ['OKC', 'POR', 6],
#  ['TOR', 'BKN', 8],
#  ['IND', 'OKC', 3],
#  ['LAL', 'NY', 14],
#  ['CLE', 'WAS', 5],
#  ['UTA', 'ATL', 25],
#  ['DET', 'PHI', 17],
#  ['TOR', 'LAC', 9],
#  ['MIA', 'MIN', 2],
#  ['NO', 'PHO', 5],
#  ['DEN', 'DAL', 23],
#  ['MEM', 'SA', 15],
#  ['CHI', 'SAC', 5],
#  ['HOU', 'ORL', 24],
#  ['POR', 'DAL', 1],
#  ['CLE', 'IND', 15],
#  ['SA', 'PHI', 8],
#  ['ATL', 'DEN', 11],
#  ['WAS', 'BKN', 4],
#  ['DET', 'LAL', 19],
#  ['MIA', 'MIL', 18],
#  ['MIN', 'TOR', 3],
#  ['UTA', 'NO', 33],
#  ['LAC', 'NY', 4],
#  ['GS', 'CHI', 31],
#  ['SAC', 'BOS', 16],
#  ['HOU', 'CHA', 12],
#  ['PHI', 'ORL', 1],
#  ['OKC', 'CLE', 9],
#  ['DAL', 'UTA', 7],
#  ['BOS', 'POR', 9],
#  ['MIA', 'BKN', 9],
#  ['SA', 'DET', 11],
#  ['DEN', 'NY', 8],
#  ['GS', 'MEM', 15],
#  ['LAL', 'MIL', 8],
#  ['NO', 'MIN', 16],
#  ['WAS', 'IND', 5],
#  ['PHO', 'CHI', 18],
#  ['SAC', 'ATL', 1],
#  ['LAC', 'CHA', 5],
#  ['MIL', 'IND', 16],
#  ['CLE', 'DEN', 16],
#  ['PHI', 'MIA', 8],
#  ['HOU', 'PHO', 31],
#  ['GS', 'OKC', 16],
#  ['DAL', 'ORL', 32],
#  ['BOS', 'UTA', 8],
#  ['MIN', 'CHI', 28],
#  ['NY', 'SA', 4],
#  ['DET', 'TOR', 1],
#  ['SAC', 'NO', 6],
#  ['PHI', 'CHA', 6],
#  ['WAS', 'OKC', 22],
#  ['MEM', 'BKN', 9],
#  ['ORL', 'MIA', 9],
#  ['SA', 'IND', 4],
#  ['MIL', 'DET', 13],
#  ['BOS', 'DAL', 13],
#  ['DEN', 'GS', 22],
#  ['NO', 'PHO', 2],
#  ['LAC', 'UTA', 16],
#  ['ATL', 'POR', 5],
#  ['CHI', 'TOR', 11],
#  ['CLE', 'MIN', 8],
#  ['SAC', 'LAL', 1],
#  ['CLE', 'IND', 9],
#  ['SA', 'ORL', 28],
#  ['BOS', 'PHI', 8],
#  ['MIL', 'BKN', 4],
#  ['DET', 'DAL', 7],
#  ['TOR', 'CHA', 5],
#  ['MIA', 'HOU', 8],
#  ['NO', 'MEM', 4],
#  ['MIN', 'DEN', 13],
#  ['PHO', 'LAL', 36],
#  ['UTA', 'POR', 23],
#  ['OKC', 'NY', 11],
#  ['GS', 'SAC', 23],
#  ['LAC', 'ATL', 15],
#  ['WAS', 'IND', 13],
#  ['CHI', 'BOS', 1],
#  ['POR', 'ORL', 9],
#  ['DET', 'CHA', 6],
#  ['CLE', 'NY', 15],
#  ['HOU', 'NO', 30],
#  ['GS', 'LAC', 10],
#  ['SAC', 'DEN', 16],
#  ['IND', 'MEM', 10],
#  ['PHI', 'WAS', 8],
#  ['TOR', 'BOS', 10],
#  ['MIA', 'ATL', 18],
#  ['CHI', 'PHO', 7],
#  ['UTA', 'MIL', 14],
#  ['MIN', 'DAL', 13],
#  ['DEN', 'BKN', 20],
#  ['SA', 'LAC', 8],
#  ['CHA', 'SAC', 14],
#  ['ORL', 'ATL', 19],
#  ['NY', 'PHI', 1],
#  ['MIA', 'IND', 18],
#  ['CHI', 'CLE', 18],
#  ['DAL', 'NO', 13],
#  ['HOU', 'MIN', 12],
#  ['GS', 'BKN', 17],
#  ['SA', 'LAL', 21],
#  ['MIL', 'PHO', 4],
#  ['MEM', 'DEN', 7],
#  ['UTA', 'WAS', 10],
#  ['BOS', 'DET', 6],
#  ['TOR', 'POR', 6],
#  ['OKC', 'NO', 8],
#  ['LAC', 'CHA', 3],
#  ['CLE', 'MIL', 7],
#  ['TOR', 'NY', 1],
#  ['GS', 'PHI', 11],
#  ['ATL', 'BOS', 16],
#  ['IND', 'HOU', 9],
#  ['DAL', 'MIA', 7],
#  ['MIN', 'SAC', 14],
#  ['WAS', 'GS', 4],
#  ['DET', 'POR', 7],
#  ['DEN', 'CHI', 18],
#  ['MEM', 'PHO', 18],
#  ['OKC', 'UTA', 3],
#  ['CHA', 'LAL', 5],
#  ['ATL', 'DAL', 5],
#  ['MIA', 'PHI', 27],
#  ['WAS', 'TOR', 9],
#  ['BOS', 'CLE', 4],
#  ['DEN', 'MIL', 12],
#  ['NO', 'DET', 23],
#  ['SA', 'IND', 1],
#  ['MIN', 'UTA', 27],
#  ['HOU', 'LAC', 19],
#  ['BKN', 'SAC', 9],
#  ['CHI', 'GS', 7],
#  ['PHO', 'CHA', 17],
#  ['POR', 'OKC', 5],
#  ['ORL', 'MIA', 11],
#  ['PHI', 'NY', 3],
#  ['TOR', 'WAS', 8],
#  ['CLE', 'ATL', 5],
#  ['MIL', 'LAC', 11],
#  ['DAL', 'MEM', 4],
#  ['PHO', 'OKC', 7],
#  ['UTA', 'BKN', 15],
#  ['SA', 'NO', 3],
#  ['BOS', 'LAL', 20],
#  ['DET', 'PHI', 30],
#  ['MIA', 'CLE', 28],
#  ['MIL', 'TOR', 7],
#  ['LAC', 'CHI', 10],
#  ['CHA', 'DEN', 10],
#  ['HOU', 'MEM', 15],
#  ['SA', 'MIN', 7],
#  ['POR', 'BKN', 14],
#  ['IND', 'ATL', 1],
#  ['GS', 'NY', 7],
#  ['PHO', 'BOS', 3],
#  ['WAS', 'ORL', 1],
#  ['UTA', 'SAC', 1],
#  ['DAL', 'OKC', 15],
#  ['NO', 'LAL', 8],
#  ['MIA', 'CLE', 8],
#  ['NY', 'ORL', 8],
#  ['MIL', 'PHI', 14],
#  ['GS', 'ATL', 8],
#  ['DET', 'CHI', 14],
#  ['CHA', 'IND', 12],
#  ['BKN', 'MEM', 13],
#  ['DEN', 'SAC', 12],
#  ['UTA', 'NO', 5],
#  ['LAC', 'BOS', 14],
#  ['DAL', 'LAL', 11],
#  ['WAS', 'PHO', 4],
#  ['ORL', 'CHI', 7],
#  ['ATL', 'BKN', 5],
#  ['MIA', 'CHA', 7],
#  ['UTA', 'HOU', 7],
#  ['IND', 'DET', 17],
#  ['MIL', 'NY', 11],
#  ['MIN', 'LAC', 16],
#  ['TOR', 'NO', 7],
#  ['SA', 'SAC', 10],
#  ['WAS', 'DEN', 10],
#  ['BOS', 'GS', 13],
#  ['DET', 'CLE', 5],
#  ['LAC', 'MEM', 16],
#  ['OKC', 'SA', 10],
#  ['POR', 'PHI', 6],
#  ['LAL', 'PHO', 12],
#  ['CHA', 'ORL', 40],
#  ['ATL', 'TOR', 6],
#  ['HOU', 'CHI', 21],
#  ['MIL', 'IND', 14],
#  ['MIN', 'GS', 1],
#  ['DAL', 'BKN', 9],
#  ['DEN', 'BOS', 20],
#  ['WAS', 'SAC', 8],
#  ['OKC', 'UTA', 8],
#  ['LAC', 'PHI', 12],
#  ['DET', 'NY', 20],
#  ['NO', 'CHA', 3],
#  ['CLE', 'ORL', 12],
#  ['MIA', 'TOR', 15],
#  ['MIL', 'MIN', 7],
#  ['SA', 'GS', 22],
#  ['PHO', 'DAL', 2],
#  ['ATL', 'MEM', 17],
#  ['WAS', 'POR', 1],
#  ['DEN', 'SAC', 13],
#  ['BOS', 'CHI', 20],
#  ['BKN', 'NY', 8],
#  ['IND', 'MIA', 4],
#  ['HOU', 'CLE', 5],
#  ['POR', 'PHO', 9],
#  ['PHI', 'LAL', 2],
#  ['CHI', 'CHA', 6],
#  ['TOR', 'DAL', 22],
#  ['MEM', 'MIL', 20],
#  ['MIN', 'WAS', 15],
#  ['SA', 'ATL', 8],
#  ['UTA', 'LAC', 6],
#  ['DEN', 'LAL', 28],
#  ['SAC', 'ORL', 5],
#  ['CLE', 'DET', 32],
#  ['OKC', 'BKN', 18],
#  ['NO', 'POR', 23],
#  ['GS', 'PHI', 2],
#  ['IND', 'CHA', 21],
#  ['DAL', 'WAS', 5],
#  ['BOS', 'MIN', 13],
#  ['UTA', 'DET', 14],
#  ['MIA', 'NO', 8],
#  ['MEM', 'CHI', 7],
#  ['POR', 'SA', 4],
#  ['SAC', 'PHO', 6],
#  ['MIL', 'LAC', 1],
#  ['CLE', 'UTA', 8],
#  ['OKC', 'TOR', 21],
#  ['MEM', 'ATL', 12],
#  ['BKN', 'NY', 11],
#  ['DEN', 'LAC', 15],
#  ['GS', 'ORL', 30],
#  ['PHI', 'DAL', 42],
#  ...]

# %%
for i in games:
    if i[0] == "CLE":
        print(i)
# Out:
# ['CLE', 'NY', 29]
# ['CLE', 'TOR', 3]
# ['CLE', 'ORL', 6]
# ['CLE', 'HOU', 8]
# ['CLE', 'BOS', 6]
# ['CLE', 'PHI', 1]
# ['CLE', 'WAS', 11]
# ['CLE', 'CHA', 7]
# ['CLE', 'TOR', 4]
# ['CLE', 'DET', 23]
# ['CLE', 'POR', 12]
# ['CLE', 'DAL', 38]
# ['CLE', 'PHI', 4]
# ['CLE', 'NY', 32]
# ['CLE', 'MIA', 30]
# ['CLE', 'CHA', 11]
# ['CLE', 'MEM', 17]
# ['CLE', 'LAL', 11]
# ['CLE', 'MIL', 6]
# ['CLE', 'MIL', 11]
# ['CLE', 'BKN', 20]
# ['CLE', 'GS', 1]
# ['CLE', 'CHA', 12]
# ['CLE', 'NO', 8]
# ['CLE', 'BKN', 8]
# ['CLE', 'PHO', 4]
# ['CLE', 'SAC', 12]
# ['CLE', 'PHO', 15]
# ['CLE', 'OKC', 16]
# ['CLE', 'MIN', 28]
# ['CLE', 'NY', 7]
# ['CLE', 'WAS', 5]
# ['CLE', 'IND', 15]
# ['CLE', 'DEN', 16]
# ['CLE', 'MIN', 8]
# ['CLE', 'IND', 9]
# ['CLE', 'NY', 15]
# ['CLE', 'MIL', 7]
# ['CLE', 'ATL', 5]
# ['CLE', 'ORL', 12]
# ['CLE', 'DET', 32]
# ['CLE', 'UTA', 8]
# ['CLE', 'LAL', 5]
# ['CLE', 'PHI', 17]
# ['CLE', 'IND', 5]
# ['CLE', 'ORL', 20]
# ['CLE', 'BOS', 23]

# %%
class Node:
    
    def __init__(self, name):
        self.name = name
        self.losses = {}
        
    def add_loss(self, oppteam, ptsDiff):
        self.losses[oppteam] = self.losses.get(oppteam, 0) + ptsDiff

# %%
nodes = {}
for i in games:
    winner = i[0]
    loser = i[1]
    ptsDiff = i[2]
    nodes[loser] = nodes.get(loser, Node(loser))
    nodes[loser].add_loss(winner, ptsDiff)

# %%
# Create Matrix
size = len(nodes.keys())
TM = np.zeros((size,size))
size
# Out:
# 30

# %%
teams = sorted(nodes.keys())
id_team = {}

# %%
for i in range(len(teams)):
    id_team[teams[i]] = i

# %%
for i in range(len(teams)):
    node = nodes[teams[i]]
    for j in node.losses.keys():
        ptsDiff = node.losses[j]
        id_col = id_team[j]
        TM[i][id_col] = float(ptsDiff)

# %%
TM
# Out:
# array([[ 0., 24.,  2., 27.,  2.,  5.,  0.,  0., 59., 13.,  0., 19., 25.,
#         22., 12., 41.,  3., 22., 18., 10.,  3., 30.,  0.,  2., 16.,  8.,
#          1., 44., 52., 33.],
#        [25.,  0., 36., 11., 71., 28., 16., 20.,  1., 33., 29., 42., 32.,
#          7.,  9., 20., 33., 20.,  9., 19., 37., 15., 16.,  0., 34., 55.,
#         17., 49., 27., 53.],
#        [23.,  0.,  0.,  0.,  7., 29.,  0., 36.,  7., 16.,  1.,  0., 14.,
#          0.,  0.,  0.,  3.,  0.,  1., 11.,  8.,  0.,  6.,  3.,  4., 13.,
#         16., 25.,  0., 40.],
#        [27.,  2., 31.,  0., 13., 30.,  0.,  0., 30., 25., 19., 37.,  8.,
#          0., 15., 20., 10.,  5.,  8.,  5.,  0.,  0., 15., 17., 17., 22.,
#          3.,  7.,  7., 20.],
#        [22.,  1., 27., 12.,  0.,  0., 26., 21., 25., 31., 25., 27., 17.,
#          6.,  7., 12., 57., 33.,  0., 37., 15.,  7., 10., 18.,  2., 19.,
#          0.,  2.,  0., 17.],
#        [19.,  0.,  4.,  0., 36.,  0.,  7., 13., 21., 35.,  5., 10., 49.,
#          0.,  8., 39., 17.,  0.,  2.,  0.,  9.,  0.,  0.,  0., 16., 32.,
#          4., 15.,  8., 12.],
#        [20.,  0., 20., 18.,  0., 38.,  0., 51., 17., 55., 47.,  9., 31.,
#          0., 25.,  4.,  0., 22., 10., 16., 12.,  8., 42., 22., 11., 25.,
#         42., 30., 24.,  0.],
#        [12.,  5.,  0., 18.,  0., 16., 20.,  0., 28., 32., 29.,  0., 17.,
#          4., 28.,  8.,  0., 16., 25.,  0., 19.,  0.,  2.,  0., 18., 66.,
#         23.,  5., 32., 17.],
#        [ 7., 10., 12., 10., 53., 55.,  0.,  0.,  0., 26.,  3., 58., 32.,
#          0., 12., 14., 41.,  0., 23., 17., 18., 38., 18.,  7.,  0., 21.,
#         11., 33., 47., 18.],
#        [ 0.,  0., 13.,  0.,  7.,  1.,  0., 22.,  0.,  0.,  5.,  0.,  0.,
#         20., 30.,  3.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 51.,
#          3.,  0.,  6.,  4.],
#        [20.,  0., 11.,  0.,  0.,  8.,  0.,  0.,  5., 33.,  0., 28., 29.,
#          6., 11., 14., 13., 14., 16.,  0.,  2.,  0.,  0.,  0., 10.,  8.,
#          0., 13., 26.,  0.],
#        [11.,  9., 22., 34., 22., 29.,  8., 36.,  0., 73.,  0.,  0.,  0.,
#         12., 13., 24., 48.,  1.,  7., 13.,  0.,  0.,  4., 20., 22.,  5.,
#          0., 36.,  9., 24.],
#        [ 0.,  5.,  5.,  0.,  0.,  0.,  2., 44., 11., 86., 43., 30.,  0.,
#          9.,  4.,  0., 12., 19.,  4.,  0., 28.,  0., 11.,  0.,  0.,  8.,
#          1.,  9.,  6.,  7.],
#        [ 0., 10., 26.,  9.,  8., 16., 72., 34., 24., 82., 39.,  7., 51.,
#          0.,  3.,  8.,  4., 41., 25.,  6., 17., 19.,  2., 40., 53., 70.,
#         25., 42., 23., 19.],
#        [17., 13., 13., 19.,  4., 17., 11.,  0., 13., 27., 39., 10., 36.,
#         19.,  0.,  9., 10., 36., 17.,  7., 23., 10.,  0.,  0.,  9., 13.,
#          5., 15.,  9.,  3.],
#        [11.,  0., 25., 15.,  8., 30.,  7.,  3., 32., 12.,  0.,  4., 16.,
#         27.,  3.,  0.,  8.,  0.,  4., 15., 12., 26., 15.,  9., 18., 11.,
#          0., 28., 11.,  0.],
#        [24.,  0., 22., 11., 15., 24., 15., 16., 15., 28., 19., 15.,  0.,
#          8., 20., 53.,  0., 17.,  6.,  5., 31., 16., 14.,  0.,  0.,  1.,
#          0., 44., 30., 11.],
#        [ 0.,  9., 19.,  7.,  0., 36., 11.,  5., 35., 35., 19.,  6., 14.,
#         12., 34., 20.,  7.,  0., 51.,  6., 34.,  0.,  2.,  0., 25., 29.,
#         13., 14., 18.,  7.],
#        [ 5., 29.,  9.,  0., 15.,  8., 23., 24., 20., 44., 62.,  3., 46.,
#         39.,  8.,  8.,  4.,  0.,  0.,  0., 28.,  7., 11.,  1., 15., 35.,
#         14.,  9., 46., 27.],
#        [ 8., 19., 49.,  5.,  0., 83.,  8., 21., 33., 20., 26., 14., 13.,
#         14., 13., 17., 12.,  0., 26.,  0., 20., 12.,  4.,  2., 15.,  8.,
#          0., 40., 12., 26.],
#        [ 2.,  0.,  0., 23., 28., 16., 15.,  6., 16., 63., 17.,  7., 24.,
#          2., 34.,  0.,  4., 10.,  0.,  0.,  0.,  2.,  0., 28., 24., 19.,
#         15., 10., 20., 22.],
#        [46., 10., 31., 87., 87., 38., 32., 21., 26., 50., 31., 57., 14.,
#         16.,  1., 12., 12., 22., 20., 19.,  8.,  0.,  1.,  5.,  9., 28.,
#          5., 49., 20.,  4.],
#        [77., 23., 13., 16., 41., 22., 18.,  8., 47., 13., 32., 29., 12.,
#         11.,  5., 50., 22., 24., 15.,  1., 31., 22.,  0.,  7.,  6., 24.,
#          2., 44., 42., 16.],
#        [ 4., 46., 10., 14.,  7., 19.,  5., 40., 17., 57., 68., 15., 45.,
#         23., 37., 15., 29., 21.,  8.,  0., 16.,  6., 15.,  0., 25., 36.,
#         50.,  0., 12.,  9.],
#        [ 5.,  0.,  9., 22., 25., 12.,  5., 12.,  8., 78., 33.,  7., 40.,
#          0.,  2.,  0., 11.,  1., 38.,  4.,  6.,  6.,  1.,  3.,  0., 36.,
#          5., 10., 42., 20.],
#        [ 2.,  0.,  0.,  0.,  4.,  0.,  4.,  0.,  0., 12.,  2.,  0., 40.,
#          7., 23.,  0.,  2.,  0., 16.,  4., 10., 12.,  0.,  3.,  5.,  0.,
#          0.,  0., 19.,  0.],
#        [11.,  9.,  5., 14.,  8., 12., 20., 25.,  0., 48., 76., 10., 34.,
#         14., 30., 17., 44., 14., 28., 11., 20.,  8.,  3.,  2., 15., 39.,
#          0.,  0., 51., 14.],
#        [10.,  0.,  5., 39., 16.,  7.,  0.,  0.,  1., 16.,  7., 18.,  8.,
#          0.,  2., 15.,  7.,  3.,  0.,  0., 21.,  9.,  5., 20.,  0., 30.,
#          8.,  0.,  0.,  9.],
#        [ 0.,  0., 19.,  6., 17.,  8.,  7., 24.,  0., 37.,  9.,  7., 29.,
#          0., 22.,  1.,  0., 27.,  0.,  0., 13.,  0.,  0.,  0., 24., 20.,
#          1., 14.,  0.,  0.],
#        [15.,  0., 17.,  5., 11., 16., 13.,  0.,  1., 24., 18.,  2.,  9.,
#          0.,  9., 22., 27., 15.,  0.,  0., 11., 10., 15.,  0.,  0., 14.,
#          0., 18., 17.,  0.]])

# %%
# Markov Matrix
MM = TM/TM.sum(axis = 1, keepdims=True)

# %%
MM
# Out:
# array([[0.        , 0.04868154, 0.0040568 , 0.05476673, 0.0040568 ,
#         0.01014199, 0.        , 0.        , 0.11967546, 0.02636917,
#         0.        , 0.03853955, 0.05070994, 0.04462475, 0.02434077,
#         0.0831643 , 0.00608519, 0.04462475, 0.03651116, 0.02028398,
#         0.00608519, 0.06085193, 0.        , 0.0040568 , 0.03245436,
#         0.01622718, 0.0020284 , 0.08924949, 0.10547667, 0.06693712],
#        [0.03272251, 0.        , 0.04712042, 0.01439791, 0.09293194,
#         0.03664921, 0.02094241, 0.02617801, 0.0013089 , 0.04319372,
#         0.03795812, 0.05497382, 0.04188482, 0.0091623 , 0.0117801 ,
#         0.02617801, 0.04319372, 0.02617801, 0.0117801 , 0.02486911,
#         0.04842932, 0.01963351, 0.02094241, 0.        , 0.04450262,
#         0.07198953, 0.02225131, 0.06413613, 0.03534031, 0.06937173],
#        [0.08745247, 0.        , 0.        , 0.        , 0.02661597,
#         0.11026616, 0.        , 0.13688213, 0.02661597, 0.0608365 ,
#         0.00380228, 0.        , 0.05323194, 0.        , 0.        ,
#         0.        , 0.01140684, 0.        , 0.00380228, 0.0418251 ,
#         0.03041825, 0.        , 0.02281369, 0.01140684, 0.01520913,
#         0.04942966, 0.0608365 , 0.09505703, 0.        , 0.15209125],
#        [0.06870229, 0.00508906, 0.07888041, 0.        , 0.03307888,
#         0.07633588, 0.        , 0.        , 0.07633588, 0.06361323,
#         0.04834606, 0.09414758, 0.02035623, 0.        , 0.03816794,
#         0.05089059, 0.02544529, 0.01272265, 0.02035623, 0.01272265,
#         0.        , 0.        , 0.03816794, 0.043257  , 0.043257  ,
#         0.05597964, 0.00763359, 0.0178117 , 0.0178117 , 0.05089059],
#        [0.04621849, 0.00210084, 0.05672269, 0.02521008, 0.        ,
#         0.        , 0.05462185, 0.04411765, 0.05252101, 0.06512605,
#         0.05252101, 0.05672269, 0.03571429, 0.01260504, 0.01470588,
#         0.02521008, 0.1197479 , 0.06932773, 0.        , 0.07773109,
#         0.03151261, 0.01470588, 0.0210084 , 0.03781513, 0.00420168,
#         0.03991597, 0.        , 0.00420168, 0.        , 0.03571429],
#        [0.05263158, 0.        , 0.01108033, 0.        , 0.09972299,
#         0.        , 0.01939058, 0.03601108, 0.05817175, 0.09695291,
#         0.01385042, 0.02770083, 0.13573407, 0.        , 0.02216066,
#         0.10803324, 0.04709141, 0.        , 0.00554017, 0.        ,
#         0.02493075, 0.        , 0.        , 0.        , 0.04432133,
#         0.08864266, 0.01108033, 0.04155125, 0.02216066, 0.033241  ],
#        [0.03338898, 0.        , 0.03338898, 0.03005008, 0.        ,
#         0.06343907, 0.        , 0.0851419 , 0.02838063, 0.0918197 ,
#         0.07846411, 0.01502504, 0.05175292, 0.        , 0.04173623,
#         0.0066778 , 0.        , 0.03672788, 0.01669449, 0.02671119,
#         0.02003339, 0.01335559, 0.07011686, 0.03672788, 0.01836394,
#         0.04173623, 0.07011686, 0.05008347, 0.04006678, 0.        ],
#        [0.02727273, 0.01136364, 0.        , 0.04090909, 0.        ,
#         0.03636364, 0.04545455, 0.        , 0.06363636, 0.07272727,
#         0.06590909, 0.        , 0.03863636, 0.00909091, 0.06363636,
#         0.01818182, 0.        , 0.03636364, 0.05681818, 0.        ,
#         0.04318182, 0.        , 0.00454545, 0.        , 0.04090909,
#         0.15      , 0.05227273, 0.01136364, 0.07272727, 0.03863636],
#        [0.0119863 , 0.01712329, 0.02054795, 0.01712329, 0.09075342,
#         0.09417808, 0.        , 0.        , 0.        , 0.04452055,
#         0.00513699, 0.09931507, 0.05479452, 0.        , 0.02054795,
#         0.0239726 , 0.07020548, 0.        , 0.03938356, 0.02910959,
#         0.03082192, 0.06506849, 0.03082192, 0.0119863 , 0.        ,
#         0.0359589 , 0.01883562, 0.05650685, 0.08047945, 0.03082192],
#        [0.        , 0.        , 0.07831325, 0.        , 0.04216867,
#         0.0060241 , 0.        , 0.13253012, 0.        , 0.        ,
#         0.03012048, 0.        , 0.        , 0.12048193, 0.18072289,
#         0.01807229, 0.        , 0.0060241 , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.30722892, 0.01807229, 0.        , 0.03614458, 0.02409639],
#        [0.07490637, 0.        , 0.0411985 , 0.        , 0.        ,
#         0.02996255, 0.        , 0.        , 0.01872659, 0.12359551,
#         0.        , 0.10486891, 0.10861423, 0.02247191, 0.0411985 ,
#         0.05243446, 0.04868914, 0.05243446, 0.05992509, 0.        ,
#         0.00749064, 0.        , 0.        , 0.        , 0.03745318,
#         0.02996255, 0.        , 0.04868914, 0.09737828, 0.        ],
#        [0.02282158, 0.0186722 , 0.04564315, 0.07053942, 0.04564315,
#         0.06016598, 0.01659751, 0.0746888 , 0.        , 0.15145228,
#         0.        , 0.        , 0.        , 0.02489627, 0.02697095,
#         0.04979253, 0.09958506, 0.00207469, 0.01452282, 0.02697095,
#         0.        , 0.        , 0.00829876, 0.04149378, 0.04564315,
#         0.01037344, 0.        , 0.0746888 , 0.0186722 , 0.04979253],
#        [0.        , 0.01453488, 0.01453488, 0.        , 0.        ,
#         0.        , 0.00581395, 0.12790698, 0.03197674, 0.25      ,
#         0.125     , 0.0872093 , 0.        , 0.02616279, 0.01162791,
#         0.        , 0.03488372, 0.05523256, 0.01162791, 0.        ,
#         0.08139535, 0.        , 0.03197674, 0.        , 0.        ,
#         0.02325581, 0.00290698, 0.02616279, 0.01744186, 0.02034884],
#        [0.        , 0.01290323, 0.03354839, 0.0116129 , 0.01032258,
#         0.02064516, 0.09290323, 0.04387097, 0.03096774, 0.10580645,
#         0.05032258, 0.00903226, 0.06580645, 0.        , 0.00387097,
#         0.01032258, 0.00516129, 0.05290323, 0.03225806, 0.00774194,
#         0.02193548, 0.02451613, 0.00258065, 0.0516129 , 0.0683871 ,
#         0.09032258, 0.03225806, 0.05419355, 0.02967742, 0.02451613],
#        [0.04207921, 0.03217822, 0.03217822, 0.0470297 , 0.00990099,
#         0.04207921, 0.02722772, 0.        , 0.03217822, 0.06683168,
#         0.09653465, 0.02475248, 0.08910891, 0.0470297 , 0.        ,
#         0.02227723, 0.02475248, 0.08910891, 0.04207921, 0.01732673,
#         0.05693069, 0.02475248, 0.        , 0.        , 0.02227723,
#         0.03217822, 0.01237624, 0.03712871, 0.02227723, 0.00742574],
#        [0.03142857, 0.        , 0.07142857, 0.04285714, 0.02285714,
#         0.08571429, 0.02      , 0.00857143, 0.09142857, 0.03428571,
#         0.        , 0.01142857, 0.04571429, 0.07714286, 0.00857143,
#         0.        , 0.02285714, 0.        , 0.01142857, 0.04285714,
#         0.03428571, 0.07428571, 0.04285714, 0.02571429, 0.05142857,
#         0.03142857, 0.        , 0.08      , 0.03142857, 0.        ],
#        [0.05217391, 0.        , 0.04782609, 0.02391304, 0.0326087 ,
#         0.05217391, 0.0326087 , 0.03478261, 0.0326087 , 0.06086957,
#         0.04130435, 0.0326087 , 0.        , 0.0173913 , 0.04347826,
#         0.11521739, 0.        , 0.03695652, 0.01304348, 0.01086957,
#         0.0673913 , 0.03478261, 0.03043478, 0.        , 0.        ,
#         0.00217391, 0.        , 0.09565217, 0.06521739, 0.02391304],
#        [0.        , 0.01923077, 0.04059829, 0.01495726, 0.        ,
#         0.07692308, 0.02350427, 0.01068376, 0.07478632, 0.07478632,
#         0.04059829, 0.01282051, 0.02991453, 0.02564103, 0.07264957,
#         0.04273504, 0.01495726, 0.        , 0.10897436, 0.01282051,
#         0.07264957, 0.        , 0.0042735 , 0.        , 0.0534188 ,
#         0.06196581, 0.02777778, 0.02991453, 0.03846154, 0.01495726],
#        [0.00925926, 0.0537037 , 0.01666667, 0.        , 0.02777778,
#         0.01481481, 0.04259259, 0.04444444, 0.03703704, 0.08148148,
#         0.11481481, 0.00555556, 0.08518519, 0.07222222, 0.01481481,
#         0.01481481, 0.00740741, 0.        , 0.        , 0.        ,
#         0.05185185, 0.01296296, 0.02037037, 0.00185185, 0.02777778,
#         0.06481481, 0.02592593, 0.01666667, 0.08518519, 0.05      ],
#        [0.01538462, 0.03653846, 0.09423077, 0.00961538, 0.        ,
#         0.15961538, 0.01538462, 0.04038462, 0.06346154, 0.03846154,
#         0.05      , 0.02692308, 0.025     , 0.02692308, 0.025     ,
#         0.03269231, 0.02307692, 0.        , 0.05      , 0.        ,
#         0.03846154, 0.02307692, 0.00769231, 0.00384615, 0.02884615,
#         0.01538462, 0.        , 0.07692308, 0.02307692, 0.05      ],
#        [0.004914  , 0.        , 0.        , 0.05651106, 0.06879607,
#         0.03931204, 0.03685504, 0.01474201, 0.03931204, 0.15479115,
#         0.04176904, 0.01719902, 0.05896806, 0.004914  , 0.08353808,
#         0.        , 0.00982801, 0.02457002, 0.        , 0.        ,
#         0.        , 0.004914  , 0.        , 0.06879607, 0.05896806,
#         0.04668305, 0.03685504, 0.02457002, 0.04914005, 0.05405405],
#        [0.06044678, 0.0131406 , 0.04073587, 0.11432326, 0.11432326,
#         0.0499343 , 0.04204993, 0.02759527, 0.03416557, 0.06570302,
#         0.04073587, 0.07490145, 0.01839685, 0.02102497, 0.00131406,
#         0.01576873, 0.01576873, 0.02890933, 0.02628121, 0.02496715,
#         0.01051248, 0.        , 0.00131406, 0.0065703 , 0.01182654,
#         0.03679369, 0.0065703 , 0.06438896, 0.02628121, 0.00525624],
#        [0.11441308, 0.03417533, 0.01931649, 0.02377415, 0.06092125,
#         0.03268945, 0.02674591, 0.01188707, 0.06983655, 0.01931649,
#         0.04754829, 0.04309064, 0.01783061, 0.01634473, 0.00742942,
#         0.07429421, 0.03268945, 0.03566122, 0.02228826, 0.00148588,
#         0.04606241, 0.03268945, 0.        , 0.01040119, 0.0089153 ,
#         0.03566122, 0.00297177, 0.0653789 , 0.06240713, 0.02377415],
#        [0.00616333, 0.07087827, 0.01540832, 0.02157165, 0.01078582,
#         0.02927581, 0.00770416, 0.06163328, 0.02619414, 0.08782743,
#         0.10477658, 0.02311248, 0.06933744, 0.03543914, 0.05701079,
#         0.02311248, 0.04468413, 0.03235747, 0.01232666, 0.        ,
#         0.02465331, 0.00924499, 0.02311248, 0.        , 0.0385208 ,
#         0.05546995, 0.0770416 , 0.        , 0.01848998, 0.01386749],
#        [0.01133787, 0.        , 0.02040816, 0.04988662, 0.05668934,
#         0.02721088, 0.01133787, 0.02721088, 0.01814059, 0.17687075,
#         0.07482993, 0.01587302, 0.09070295, 0.        , 0.00453515,
#         0.        , 0.02494331, 0.00226757, 0.0861678 , 0.00907029,
#         0.01360544, 0.01360544, 0.00226757, 0.00680272, 0.        ,
#         0.08163265, 0.01133787, 0.02267574, 0.0952381 , 0.04535147],
#        [0.01212121, 0.        , 0.        , 0.        , 0.02424242,
#         0.        , 0.02424242, 0.        , 0.        , 0.07272727,
#         0.01212121, 0.        , 0.24242424, 0.04242424, 0.13939394,
#         0.        , 0.01212121, 0.        , 0.0969697 , 0.02424242,
#         0.06060606, 0.07272727, 0.        , 0.01818182, 0.03030303,
#         0.        , 0.        , 0.        , 0.11515152, 0.        ],
#        [0.01890034, 0.01546392, 0.00859107, 0.02405498, 0.0137457 ,
#         0.02061856, 0.03436426, 0.04295533, 0.        , 0.08247423,
#         0.13058419, 0.01718213, 0.05841924, 0.02405498, 0.05154639,
#         0.02920962, 0.07560137, 0.02405498, 0.04810997, 0.01890034,
#         0.03436426, 0.0137457 , 0.00515464, 0.00343643, 0.0257732 ,
#         0.06701031, 0.        , 0.        , 0.08762887, 0.02405498],
#        [0.0390625 , 0.        , 0.01953125, 0.15234375, 0.0625    ,
#         0.02734375, 0.        , 0.        , 0.00390625, 0.0625    ,
#         0.02734375, 0.0703125 , 0.03125   , 0.        , 0.0078125 ,
#         0.05859375, 0.02734375, 0.01171875, 0.        , 0.        ,
#         0.08203125, 0.03515625, 0.01953125, 0.078125  , 0.        ,
#         0.1171875 , 0.03125   , 0.        , 0.        , 0.03515625],
#        [0.        , 0.        , 0.06666667, 0.02105263, 0.05964912,
#         0.02807018, 0.0245614 , 0.08421053, 0.        , 0.12982456,
#         0.03157895, 0.0245614 , 0.10175439, 0.        , 0.07719298,
#         0.00350877, 0.        , 0.09473684, 0.        , 0.        ,
#         0.04561404, 0.        , 0.        , 0.        , 0.08421053,
#         0.07017544, 0.00350877, 0.04912281, 0.        , 0.        ],
#        [0.05190311, 0.        , 0.05882353, 0.01730104, 0.03806228,
#         0.05536332, 0.0449827 , 0.        , 0.00346021, 0.08304498,
#         0.06228374, 0.00692042, 0.03114187, 0.        , 0.03114187,
#         0.07612457, 0.09342561, 0.05190311, 0.        , 0.        ,
#         0.03806228, 0.03460208, 0.05190311, 0.        , 0.        ,
#         0.04844291, 0.        , 0.06228374, 0.05882353, 0.        ]])

# %%
# PageRank
w, vl, vr = la.eig(MM, left = True)
vl = np.absolute(vl[:,0].T)

# %%
rankings = []
teams = sorted(id_team.keys())

# %%
for i in range(30):
    index = np.argmax(vl)
    rankings.append(teams[index])
    vl[index] = 0

# %%
rankings = rankings[:15]

# %%
df_pagerank = pd.DataFrame(rankings, columns = ["team"])

# %%
df_pagerank
# Out:
#    team
# 0    GS
# 1    SA
# 2   LAC
# 3   MEM
# 4   UTA
# 5   HOU
# 6   DEN
# 7   TOR
# 8   CLE
# 9   OKC
# 10  BOS
# 11  CHI
# 12  IND
# 13  DET
# 14  LAL

# %%
df_standings = pd.read_csv("2016-17_standings.csv")

# %%
df_standings
# Out:
#           stDate teamAbbr  rank rankOrd  gameWon  gameLost stk stkType  \
# 0     2016-10-25      ATL     2     2nd        0         0   -       -
# 1     2016-10-25      BKN     2     2nd        0         0   -       -
# 2     2016-10-25      BOS     2     2nd        0         0   -       -
# 3     2016-10-25      CHA     2     2nd        0         0   -       -
# 4     2016-10-25      CHI     2     2nd        0         0   -       -
# ...          ...      ...   ...     ...      ...       ...  ..     ...
# 4795  2017-04-12       SA     2     2nd       61        21  L3    loss
# 4796  2017-04-12      SAC    12    12th       32        50  L1    loss
# 4797  2017-04-12      TOR     2     2nd       51        31  W4     win
# 4798  2017-04-12      UTA     4     4th       51        31  W2     win
# 4799  2017-04-12      WAS     4     4th       49        33  L1    loss
#
#       stkTot  gameBack  ...  rel%Indx     mov     srs     pw%  pyth%13.91  \
# 0          0       0.5  ...  0.000000  0.0000  0.0000  0.5000      0.0000
# 1          0       0.5  ...  0.000000  0.0000  0.0000  0.5000      0.0000
# 2          0       0.5  ...  0.000000  0.0000  0.0000  0.5000      0.0000
# 3          0       0.5  ...  0.000000  0.0000  0.0000  0.5000      0.0000
# 4          0       0.5  ...  0.000000  0.0000  0.0000  0.5000      0.0000
# ...      ...       ...  ...       ...     ...     ...     ...         ...
# 4795       3       6.0  ...  0.559475  7.1951  6.6971  0.7369      0.7279
# 4796       1      35.0  ...  0.478375 -3.8780 -4.3858  0.3723      0.3740
# 4797       4       2.0  ...  0.524750  4.2073  3.7150  0.6385      0.6362
# 4798       2      16.0  ...  0.530725  3.9390  3.4387  0.6297      0.6353
# 4799       1       4.0  ...  0.519500  1.7805  1.2870  0.5586      0.5569
#
#       wpyth13.91  lpyth13.91  pyth%16.5  wpyth16.5  lpyth16.5
# 0         0.0000     82.0000     0.0000     0.0000    82.0000
# 1         0.0000     82.0000     0.0000     0.0000    82.0000
# 2         0.0000     82.0000     0.0000     0.0000    82.0000
# 3         0.0000     82.0000     0.0000     0.0000    82.0000
# 4         0.0000     82.0000     0.0000     0.0000    82.0000
# ...          ...         ...        ...        ...        ...
# 4795     59.6878     22.3122     0.7627    62.5414    19.4586
# 4796     30.6680     51.3320     0.3518    28.8476    53.1524
# 4797     52.1684     29.8316     0.6599    54.1118    27.8882
# 4798     52.0946     29.9054     0.6589    54.0298    27.9702
# 4799     45.6658     36.3342     0.5674    46.5268    35.4732
#
# [4800 rows x 39 columns]

# %%
df_rank = df_standings[['stDate', 'teamAbbr', 'rank']]

# %%
df_rank
# Out:
#           stDate teamAbbr  rank
# 0     2016-10-25      ATL     2
# 1     2016-10-25      BKN     2
# 2     2016-10-25      BOS     2
# 3     2016-10-25      CHA     2
# 4     2016-10-25      CHI     2
# ...          ...      ...   ...
# 4795  2017-04-12       SA     2
# 4796  2017-04-12      SAC    12
# 4797  2017-04-12      TOR     2
# 4798  2017-04-12      UTA     4
# 4799  2017-04-12      WAS     4
#
# [4800 rows x 3 columns]

# %%
ranked = df_rank.groupby("teamAbbr").mean()

# %%
df_ranked = ranked.sort_values("rank", ascending = True)

# %%
df_ranked
# Out:
#               rank
# teamAbbr
# CLE        1.06250
# GS         1.48125
# SA         2.06250
# TOR        2.91250
# BOS        3.13125
# HOU        3.51875
# LAC        3.76250
# ATL        4.86875
# UTA        5.17500
# OKC        5.69375
# MEM        5.96875
# CHI        6.56875
# CHA        6.76875
# IND        6.84375
# WAS        7.06875
# MIL        7.30625
# POR        8.10625
# DET        8.61250
# DEN        8.66250
# NY         9.78750
# SAC       10.18125
# MIA       10.90000
# NO        11.73750
# LAL       11.88125
# MIN       11.95000
# ORL       12.25625
# DAL       12.45000
# PHI       13.53750
# PHO       13.66250
# BKN       13.94375
